# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd .read_excel('Indian stock market final sheet Part 1.xlsx')

# %%
# read the database
df.head()
# Out:
#                             Name     Ticker                        Sub-Sector  \
# 0        Reliance Industries Ltd   RELIANCE  Oil & Gas - Refining & Marketing
# 1  Tata Consultancy Services Ltd        TCS          IT Services & Consulting
# 2                  HDFC Bank Ltd   HDFCBANK                     Private Banks
# 3                    Infosys Ltd       INFY          IT Services & Consulting
# 4                 ICICI Bank Ltd  ICICIBANK                     Private Banks
#
#      Market Cap  Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 0  1.679534e+06      2467.40  34.186904          7.793277          3.957021
# 1  1.358569e+06      3626.70  41.892356         37.740680         25.932382
# 2  8.206363e+05      1486.50  25.779258         16.435200          1.883433
# 3  7.775010e+05      1853.05  40.178853         27.135305         19.417895
# 4  5.002790e+05       710.75  27.212283         12.382897          1.243333
#
# ...

# %%
# inspecting the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Name                            2000 non-null   object
#  1   Ticker                          2000 non-null   object
#  2   Sub-Sector                      1947 non-null   object
#  3   Market Cap                      2000 non-null   float64
#  4   Close Price                     2000 non-null   float64
#  5   PE Ratio                        1957 non-null   float64
#  6   Return on Equity                1870 non-null   float64
#  7   Return on Assets                1952 non-null   float64
#  8   Net Profit Margin               1953 non-null   float64
#  9   5Y Avg EBITDA Margin            1880 non-null   float64
#  10  EBITDA Margin                   1953 non-null   float64
#  11  1Y Return vs Nifty              2000 non-null   float64
# ...

# %%
df.dtypes
# Out:
# Name                               object
# Ticker                             object
# Sub-Sector                         object
# Market Cap                        float64
# Close Price                       float64
# PE Ratio                          float64
# Return on Equity                  float64
# Return on Assets                  float64
# Net Profit Margin                 float64
# 5Y Avg EBITDA Margin              float64
# EBITDA Margin                     float64
# 1Y Return vs Nifty                float64
# 5Y CAGR                           float64
# Debt to Equity                    float64
# Long Term Debt to Equity          float64
# Net Income / Liabilities          float64
# 5Y Historical Revenue Growth      float64
# 5Y Historical EBITDA Growth       float64
# 5Y Hist Op. Cash Flow Growth      float64
# 5Y Historical EPS Growth          float64
# Forward PE Ratio                  float64
# Enterprise Value                  float64
# ...

# %%
df.shape
# Out:
# (2000, 44)

# %%
df[df['Enterprise Value'].isna()]
# Out:
#                         Name Ticker    Sub-Sector  Market Cap  Close Price  \
# 1972  Uttam Value Steels Ltd   UVSL  Iron & Steel  132.161527          0.2
#
#       PE Ratio  Return on Equity  Return on Assets  Net Profit Margin  \
# 1972 -0.363636               NaN        -19.453501         -17.835319
#
#       5Y Avg EBITDA Margin  ...  Net Income     PBT  Earnings Per Share  \
# 1972              -7.95187  ...     -363.96 -363.96               -0.55
#
#       EBITDA  Long Term Investments  Reserves & Surplus  Cash and Equivalent  \
# 1972 -245.78                  79.41            -2299.57                12.55
#
#       Book Value  Free Cash Flow  Operating Cash Flow
# 1972         NaN            9.09                 9.09
#
# [1 rows x 44 columns]

# %%
df['Enterprise Value']
# Out:
# 0       1.879599e+06
# 1       1.328550e+06
# 2       6.999965e+05
# 3       7.562010e+05
# 4       3.622968e+05
#             ...
# 1995    1.211677e+02
# 1996    3.854888e+02
# 1997    1.809056e+02
# 1998    1.641462e+02
# 1999    1.410350e+02
# Name: Enterprise Value, Length: 2000, dtype: float64

# %% [markdown]
#  **Firstly, screen the companies and visualise them according to sub-sectors using a pie chart  or a bar charts**

# %%
df.head(2)
# Out:
#                             Name    Ticker                        Sub-Sector  \
# 0        Reliance Industries Ltd  RELIANCE  Oil & Gas - Refining & Marketing
# 1  Tata Consultancy Services Ltd       TCS          IT Services & Consulting
#
#      Market Cap  Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 0  1.679534e+06       2467.4  34.186904          7.793277          3.957021
# 1  1.358569e+06       3626.7  41.892356         37.740680         25.932382
#
#    Net Profit Margin  5Y Avg EBITDA Margin  ...  Net Income      PBT  \
# 0           9.725370             17.720494  ...     49128.0  55461.0
# 1          19.383065             29.072528  ...     32430.0  43760.0
#
#    Earnings Per Share    EBITDA  Long Term Investments  Reserves & Surplus  \
# 0           74.653049  103222.0               212382.0            579376.0
# 1           87.043624   48462.0                  213.0             86063.0
#
# ...

# %%
# cleaning the data by removing the na value
df=df[-df['Sub-Sector'].isna()]

# %%
plt.figure(figsize=(27,14))
df['Sub-Sector'].value_counts()[:50].plot.bar()
plt.title("Sub-Sector  of Company",fontdict={'fontsize':30,'fontweight':5,'color':'Green'})
plt.xlabel("Sub Sector company",fontdict={'fontsize':20})
plt.ylabel('Number of comapny',fontdict={'fontsize':20})
# Out:
# Text(0, 0.5, 'Number of comapny')

# %%
df.head(4)
# Out:
#                             Name    Ticker                        Sub-Sector  \
# 0        Reliance Industries Ltd  RELIANCE  Oil & Gas - Refining & Marketing
# 1  Tata Consultancy Services Ltd       TCS          IT Services & Consulting
# 2                  HDFC Bank Ltd  HDFCBANK                     Private Banks
# 3                    Infosys Ltd      INFY          IT Services & Consulting
#
#      Market Cap  Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 0  1.679534e+06      2467.40  34.186904          7.793277          3.957021
# 1  1.358569e+06      3626.70  41.892356         37.740680         25.932382
# 2  8.206363e+05      1486.50  25.779258         16.435200          1.883433
# 3  7.775010e+05      1853.05  40.178853         27.135305         19.417895
#
#    Net Profit Margin  5Y Avg EBITDA Margin  ...  Net Income       PBT  \
# 0           9.725370             17.720494  ...     49128.0  55461.00
# ...

# %% [markdown]
# **Secondly, visualise the companies by segregating them according to Market Cap in
# three categories: Large Cap(>20,000 crore), Mid Cap (5,000 to 20,000 crore) &
# Small Cap(<5,000)**.

# %%
#rounding of market-cap
df['Market Cap']=df['Market Cap'].apply(lambda x : round(x))

# %%
def Market_Cap(x):
    if x>20000:
        return "Large Cap"
    elif x<=20000 and x>=5000:
        return "Medium Cap"
    else:
        return 'Small Cap'

# %%
df['Market_Cap_company']=df['Market Cap'].apply(Market_Cap)

# %%
df['Market_Cap_company'].value_counts().plot.pie(autopct='%2.1f%%')
# Out:
# <AxesSubplot:ylabel='Market_Cap_company'>

# %%
#picking up 10 comapny
df2=df.iloc[[1,5,10,16,79,151,278,300,368,336]]

# %%
df2.shape
# Out:
# (10, 45)

# %%
df2.isna().sum()
# Out:
# Name                              0
# Ticker                            0
# Sub-Sector                        0
# Market Cap                        0
# Close Price                       0
# PE Ratio                          0
# Return on Equity                  0
# Return on Assets                  0
# Net Profit Margin                 0
# 5Y Avg EBITDA Margin              0
# EBITDA Margin                     0
# 1Y Return vs Nifty                0
# 5Y CAGR                           0
# Debt to Equity                    1
# Long Term Debt to Equity          1
# Net Income / Liabilities          0
# 5Y Historical Revenue Growth      0
# 5Y Historical EBITDA Growth       0
# 5Y Hist Op. Cash Flow Growth      1
# 5Y Historical EPS Growth          0
# Forward PE Ratio                  1
# Enterprise Value                  0
# PB Ratio                          0
# Dividend Yield                    2
# PE Premium vs Sector              0
# Domestic Institutional Holding    0
# ...

# %%
df2
# Out:
#                                   Name      Ticker  \
# 1        Tata Consultancy Services Ltd         TCS
# 5               Hindustan Unilever Ltd  HINDUNILVR
# 10             Kotak Mahindra Bank Ltd   KOTAKBANK
# 16               Avenue Supermarts Ltd       DMART
# 79                  Ambuja Cements Ltd   AMBUJACEM
# 152      Power Finance Corporation Ltd         PFC
# 279  IRB Infrastructure Developers Ltd         IRB
# 301                   TTK Prestige Ltd  TTKPRESTIG
# 369            Zensar Technologies Ltd  ZENSARTECH
# 337          Balrampur Chini Mills Ltd  BALRAMCHIN
#
#                         Sub-Sector  Market Cap  Close Price    PE Ratio  \
# 1         IT Services & Consulting     1358569      3626.70   41.892356
# 5        FMCG - Household Products      493896      2051.20   61.775589
# 10                   Private Banks      361606      1777.10   36.196038
# 16      Retail - Department Stores      271600      4095.20  247.023553
# ...

# %%
df2.isnull().sum()
# Out:
# Name                              0
# Ticker                            0
# Sub-Sector                        0
# Market Cap                        0
# Close Price                       0
# PE Ratio                          0
# Return on Equity                  0
# Return on Assets                  0
# Net Profit Margin                 0
# 5Y Avg EBITDA Margin              0
# EBITDA Margin                     0
# 1Y Return vs Nifty                0
# 5Y CAGR                           0
# Debt to Equity                    1
# Long Term Debt to Equity          1
# Net Income / Liabilities          0
# 5Y Historical Revenue Growth      0
# 5Y Historical EBITDA Growth       0
# 5Y Hist Op. Cash Flow Growth      1
# 5Y Historical EPS Growth          0
# Forward PE Ratio                  1
# Enterprise Value                  0
# PB Ratio                          0
# Dividend Yield                    2
# PE Premium vs Sector              0
# Domestic Institutional Holding    0
# ...

# %%
df2['5Y CAGR']=df2['5Y CAGR'].apply(lambda x :round(x) )
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\2462749942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['5Y CAGR']=df2['5Y CAGR'].apply(lambda x :round(x) )

# %%
#  3 cases of growth (g): Assume 3 Cases for g (Growth) : Good (15% Growth) ; Bad (-5% Growth); Best (25%Growth
def GROWTH(x):
    if x >20:
        return 'Best'
    elif x<20 and x>5:
        return 'Good'
    else :
        return 'Bad'

# %%
df2['growth']=df2['5Y CAGR'].apply(GROWTH)
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\3508583801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['growth']=df2['5Y CAGR'].apply(GROWTH)

# %%
df2['growth'].value_counts().plot.bar()
plt.title(" 5Y CAGR. Compound annual growth rate ")
plt.xlabel("Growth")
# Out:
# Text(0.5, 0, 'Growth')

# %%
# finding intrensic value

# %%
#  V = (EPS * (8.5 + 2g) * 6) / Y

# %%
df2['5Y Historical EPS Growth']=df2['5Y Historical EPS Growth'].apply(lambda x: round(x,2))
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\1371326348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['5Y Historical EPS Growth']=df2['5Y Historical EPS Growth'].apply(lambda x: round(x,2))

# %%
def Internsicvalue(x):
    EPS=x['Earnings Per Share']
    g=x['']

# %%
df2['Earnings Per Share']=df2['Earnings Per Share'].apply(lambda x: round(x,1))
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\1978756758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Earnings Per Share']=df2['Earnings Per Share'].apply(lambda x: round(x,1))

# %%
df2.head(2)
# Out:
#                             Name      Ticker                 Sub-Sector  \
# 1  Tata Consultancy Services Ltd         TCS   IT Services & Consulting
# 5         Hindustan Unilever Ltd  HINDUNILVR  FMCG - Household Products
#
#    Market Cap  Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 1     1358569       3626.7  41.892356         37.740680         25.932382
# 5      493896       2051.2  61.775589         28.584197         17.987918
#
#    Net Profit Margin  5Y Avg EBITDA Margin  ...  Earnings Per Share   EBITDA  \
# 1          19.383065             29.072528  ...                87.0  48462.0
# 5          16.812112             23.118521  ...                35.4  11796.0
#
#    Long Term Investments  Reserves & Surplus  Cash and Equivalent  Book Value  \
# 1                  213.0             86063.0              38489.0     87108.0
# 5                    2.0              7089.0               7178.0     47694.0
#
# ...

# %%
df2['yield']=df2['Operating Cash Flow']+df2['Free Cash Flow']
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\3292013033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['yield']=df2['Operating Cash Flow']+df2['Free Cash Flow']

# %%
df2['yield']=round(df2['yield']/df2['Close Price'],2)
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\931155735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['yield']=round(df2['yield']/df2['Close Price'],2)

# %%
df2.head(2)
# Out:
#                             Name      Ticker                 Sub-Sector  \
# 1  Tata Consultancy Services Ltd         TCS   IT Services & Consulting
# 5         Hindustan Unilever Ltd  HINDUNILVR  FMCG - Household Products
#
#    Market Cap  Close Price   PE Ratio  Return on Equity  Return on Assets  \
# 1     1358569       3626.7  41.892356         37.740680         25.932382
# 5      493896       2051.2  61.775589         28.584197         17.987918
#
#    Net Profit Margin  5Y Avg EBITDA Margin  ...   EBITDA  \
# 1          19.383065             29.072528  ...  48462.0
# 5          16.812112             23.118521  ...  11796.0
#
#    Long Term Investments  Reserves & Surplus  Cash and Equivalent  Book Value  \
# 1                  213.0             86063.0              38489.0     87108.0
# 5                    2.0              7089.0               7178.0     47694.0
#
#    Free Cash Flow  Operating Cash Flow  Market_Cap_company  growth  yield
# ...

# %%
# Find the Intrinsic Value of the company based on 3 cases of growth (g): Assume 3 Cases for g (Growth) : Good (15% Growth) ; Bad (-5% Growth); Best (25%Growth)
def Interensic_value(x):
    EPS=x['Earnings Per Share']
    Y=x['yield']
    g=x['5Y CAGR']
    return (EPS*(8.5+2*g)*6)/Y

# %%
df2['Intrensic_values']=df2.apply(Interensic_value,axis=1)
# Out:
# C:\Users\Bijoy\AppData\Local\Temp\ipykernel_7448\1142998531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Intrensic_values']=df2.apply(Interensic_value,axis=1)

# %%
df2
# Out:
#                                   Name      Ticker  \
# 1        Tata Consultancy Services Ltd         TCS
# 5               Hindustan Unilever Ltd  HINDUNILVR
# 10             Kotak Mahindra Bank Ltd   KOTAKBANK
# 16               Avenue Supermarts Ltd       DMART
# 79                  Ambuja Cements Ltd   AMBUJACEM
# 152      Power Finance Corporation Ltd         PFC
# 279  IRB Infrastructure Developers Ltd         IRB
# 301                   TTK Prestige Ltd  TTKPRESTIG
# 369            Zensar Technologies Ltd  ZENSARTECH
# 337          Balrampur Chini Mills Ltd  BALRAMCHIN
#
#                         Sub-Sector  Market Cap  Close Price    PE Ratio  \
# 1         IT Services & Consulting     1358569      3626.70   41.892356
# 5        FMCG - Household Products      493896      2051.20   61.775589
# 10                   Private Banks      361606      1777.10   36.196038
# 16      Retail - Department Stores      271600      4095.20  247.023553
# ...

# %%
plt.plot(df2['Market Cap'], df2['5Y CAGR'])
plt.xlabel('Market Cap')
plt.ylabel('GROWTH')
plt.title("Growth vs MarketCap")
# Out:
# Text(0.5, 1.0, 'Growth vs MarketCap')

# %%
df2['Market Cap']
# Out:
# 1      1358569
# 5       493896
# 10      361606
# 16      271600
# 79       60800
# 152      30717
# 279      13826
# 301      11921
# 369       8526
# 337       9781
# Name: Market Cap, dtype: int64
